# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from qutip import *

# %%
res_list = []

for i in range(21):
    res_list.append(qload('itj_{}'.format(i+1)))
    
res_list[0].states[-1]
# Out:
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Quantum object: dims = [[2, 2, 2, 2], [1, 1, 1, 1]], shape = (16, 1), type = ket
# Qobj data =
# [[ 1.96052611e-04+1.63358894e-03j]
#  [-1.79279803e-01+1.83547120e-01j]
#  [-1.91561266e-01+1.81607978e-01j]
#  [-1.91774575e-01+1.63834342e-01j]
#  [-5.78037422e-04+1.12002560e-04j]
#  [-1.67199821e-01+1.78591728e-01j]
#  [-1.88783488e-01+1.84888912e-01j]
#  [-1.84798851e-01+1.61600207e-01j]
#  [ 2.20558334e-01-2.47829195e-01j]
#  [-1.76313751e-01+1.85217270e-01j]
#  [-1.80409234e-01+1.74084940e-01j]
#  [-1.86196647e-01+1.63976327e-01j]
#  [-2.23395049e-01+2.46081839e-01j]
#  [-1.74231093e-01+1.90062195e-01j]
#  [-1.87410011e-01+1.84949442e-01j]
#  [-1.87845111e-01+1.71774794e-01j]]

# %%
res00_list = []
res01_list = []
res10_list = []
res11_list = []

for i in range(10):
    res00_list.append(expect(ptrace(res_list[2*i+1].states[-1], [2,3]), tensor(basis(2,0),basis(2,0))))
    res01_list.append(expect(ptrace(res_list[2*i+1].states[-1], [2,3]), tensor(basis(2,0),basis(2,1))))
    res10_list.append(expect(ptrace(res_list[2*i+1].states[-1], [2,3]), tensor(basis(2,1),basis(2,0))))
    res11_list.append(expect(ptrace(res_list[2*i+1].states[-1], [2,3]), tensor(basis(2,1),basis(2,1))))

# %%
plt.plot(np.abs(res00_list))

# %%
plt.plot(np.abs(res01_list))

# %%
plt.plot(np.abs(res10_list))

# %%
plt.plot(np.abs(res11_list))

# %%
[np.mean(res00_list),np.mean(res01_list),np.mean(res10_list),np.mean(res11_list)]
# Out:
# [0.2780544299102786,
#  0.16836827032694185,
#  0.29682547660875297,
#  0.25675182315402656]

# %%
np.mean(res00_list)+np.mean(res01_list)+np.mean(res10_list)+np.mean(res11_list)
# Out:
# 1.0
