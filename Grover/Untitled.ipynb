# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from qutip import *

# %%
res = []

for i in range(7): #7
    res.append(qload('it_{}'.format(i+1)))
# Out:
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0

# %%
np.abs(res[3].states[-1][15][0,0])**2
# Out:
# 2.983757907802307e-07

# %%
a = [[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[]]

for i in range(2):
    for j in range(2):
        for k in range(2):
            for l in range(2):
                for m in range(7): #7
                    a[8*i+4*j+2*k+l].append(np.abs(res[m].states[-1][8*i+4*j+2*k+l][0,0])**2)

# %%
[a[i][-1] for i in range(16)]
# Out:
# [2.649647979947965e-06,
#  2.179779686142165e-06,
#  5.48326644790345e-06,
#  8.560165615502872e-06,
#  0.2513690417220198,
#  0.2501958296942852,
#  6.859504848855091e-06,
#  9.018767933780996e-07,
#  7.63911534905179e-06,
#  3.950484560895316e-06,
#  1.1956046122620794e-05,
#  1.2995532100689116e-05,
#  0.24953481463699687,
#  0.24883593785767652,
#  1.1913442066953556e-06,
#  9.32531007464778e-09]

# %%
for i in range(16):
    plt.plot(a[i])

# %%
plt.plot(a[0])
plt.plot(a[-1])
