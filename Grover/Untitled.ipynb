# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from qutip import *

# %%
res = []

for i in range(7): #7
    res.append(qload('it_{}'.format(i+1)))
# Out:
# Loaded Result object:
# Result object with mesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with mesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with mesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with mesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with mesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with mesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with mesolve data.
# --------------------------------
# states = True
# num_collapse = 0

# %%
res[3].states[-1][0,0]
# Out:
# (0.11627492907558307-9.719988297515193e-13j)

# %%
a = [[1/16],[1/16],[1/16],[1/16],[1/16],[1/16],[1/16],[1/16],[1/16],[1/16],[1/16],[1/16],[1/16],[1/16],[1/16],[1/16]]

for i in range(2):
    for j in range(2):
        for k in range(2):
            for l in range(2):
                for m in range(7): #7
                    a[8*i+4*j+2*k+l].append(np.abs(res[m].states[-1][8*i+4*j+2*k+l,8*i+4*j+2*k+l]))

# %%
[a[i][-1] for i in range(16)]
# Out:
# [0.13879448244388984,
#  0.07369061876861938,
#  0.0858180248484683,
#  0.051693455328229915,
#  0.09386663221779475,
#  0.055553055268572245,
#  0.06626343385585579,
#  0.04466007779458462,
#  0.07293860765728395,
#  0.04630300118203775,
#  0.05168189231198693,
#  0.03726793066259889,
#  0.05344690320366623,
#  0.03856616028783076,
#  0.046009166721985476,
#  0.04344655745284236]

# %%
for i in range(16):
    plt.plot(a[i])

# %%
plt.plot(a[0])
plt.plot(a[-1])

# %%
s = 0
for i in range(16):
    s += a[i][-1]

s
# Out:
# 0.02280895786309954
