# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from qutip import *

# %%
res = []

for i in range(7): #7
    res.append(qload('it_{}'.format(i+1)))
# Out:
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with sesolve data.
# --------------------------------
# states = True
# num_collapse = 0

# %%
np.abs(res[3].states[-1][15][0,0])**2
res[3].states[-1][15]
# Out:
# array([[-0.18722735-0.19005677j]])

# %%
a = [[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[]]

for i in range(2):
    for j in range(2):
        for k in range(2):
            for l in range(2):
                for m in range(7): #7
                    a[8*i+4*j+2*k+l].append(np.abs(res[m].states[-1][8*i+4*j+2*k+l][0,0]))

# %%
'''
a = []
a += [[1/8,-(1/16),-(7/32),-(17/64),-(23/128),-(1/ 256),89/512]]
a += [[1/8,-(1/16),-(7/32),-(17/64),-(23/ 128),-(1/256),89/512]]
a += [[1/8,-(1/16),-(7/32),-(17/ 64),-(23/128),-(1/256),89/512]]
a += [[1/8,-(1/16),-(7/ 32),-(17/64),-(23/128),-(1/256),89/512]]
a += [[1/8,-(1/16),-(7/32),-(17/64),-(23/128),-(1/256),89/512]]
a += [[1/8,-(1/ 16),-(7/32),-(17/64),-(23/128),-(1/ 256),89/ 512]]
a += [[1/8,-(1/16),-(7/32),-(17/64),-(23/ 128),-(1/256),89/512]]
a += [[1/8,-(1/16),-(7/32),-(17/ 64),-(23/128),-(1/256),89/512]]
a += [[1/8,-(1/16),-(7/32),-(17/64),-(23/128),-(1/256),89/512]]
a += [[5/ 8,11/ 16,13/ 32,-(5/64),-(67/128),-(181/256),-(275/512)]]
a += [[1/8,-(1/16),-(7/32),-(17/64),-(23/128),-(1/ 256),89/512]]
a += [[1/8,-(1/16),-(7/32),-(17/64),-(23/ 128),-(1/256),89/ 512]]
a += [[1/8,-(1/16),-(7/32),-(17/ 64),-(23/128),-(1/256),89/512]]
a += [[5/8,11/ 16,13/ 32,-(5/64),-(67/128),-(181/256),-(275/512)]]
a += [[1/8,-(1/16),-(7/32),-(17/64),-(23/128),-(1/256),89/512]]
a += [[1/ 8,-(1/16),-(7/32),-(17/64),-(23/128),-(1/ 256),89/512]]
'''

sum = 0
for i in range(16):
    sum += (a[i][-1])**2
    
print(sum)
# Out:
# 1.0

# %%
fig, axes = plt.subplots(1, 1, sharex=True, figsize=(12,8))

for i in range(16):
    if i == 9:
        axes.plot(np.abs([1/np.sqrt(16)]+a[i])**2, c='b', label='ω = 9')
    elif i == 13:
        axes.plot(np.abs([1/np.sqrt(16)]+a[i])**2, c='g', label='ω = 13')
    elif i == 0:
        axes.plot(np.abs([1/np.sqrt(16)]+a[i])**2, c='k', label='Otros estados')
    else:
        axes.plot(np.abs([1/np.sqrt(16)]+a[i])**2, c='k')
axes.set_xlabel('Iteración')
axes.set_ylabel('Probabilidad')
axes.set_ylim(0,0.6)
axes.legend()
#fig.savefig('../../img/grover2M.eps', format='eps')
fig.savefig('../../img/grover2lossless.eps', format='eps')

# %%
a = []
a += [[1/8,-(1/16),-(7/32),-(17/64),-(23/128),-(1/ 256),89/512]]
a += [[1/8,-(1/16),-(7/32),-(17/64),-(23/ 128),-(1/256),89/512]]
a += [[1/8,-(1/16),-(7/32),-(17/ 64),-(23/128),-(1/256),89/512]]
a += [[1/8,-(1/16),-(7/ 32),-(17/64),-(23/128),-(1/256),89/512]]
a += [[1/8,-(1/16),-(7/32),-(17/64),-(23/128),-(1/256),89/512]]
a += [[1/8,-(1/ 16),-(7/32),-(17/64),-(23/128),-(1/ 256),89/ 512]]
a += [[1/8,-(1/16),-(7/32),-(17/64),-(23/ 128),-(1/256),89/512]]
a += [[1/8,-(1/16),-(7/32),-(17/ 64),-(23/128),-(1/256),89/512]]
a += [[1/8,-(1/16),-(7/32),-(17/64),-(23/128),-(1/256),89/512]]
a += [[5/ 8,11/ 16,13/ 32,-(5/64),-(67/128),-(181/256),-(275/512)]]
a += [[1/8,-(1/16),-(7/32),-(17/64),-(23/128),-(1/ 256),89/512]]
a += [[1/8,-(1/16),-(7/32),-(17/64),-(23/ 128),-(1/256),89/ 512]]
a += [[1/8,-(1/16),-(7/32),-(17/ 64),-(23/128),-(1/256),89/512]]
a += [[5/8,11/ 16,13/ 32,-(5/64),-(67/128),-(181/256),-(275/512)]]
a += [[1/8,-(1/16),-(7/32),-(17/64),-(23/128),-(1/256),89/512]]
a += [[1/ 8,-(1/16),-(7/32),-(17/64),-(23/128),-(1/ 256),89/512]]


sum = 0
for i in range(16):
    sum += (a[i][-1])**2
    
print(sum)
# Out:
# 1.0

# %%
fig, axes = plt.subplots(1, 1, sharex=True, figsize=(12,8))

for i in range(16):
    if i == 9:
        axes.plot(np.abs([1/np.sqrt(16)]+a[i])**2, c='b', label='ω = 9')
    elif i == 13:
        axes.plot(np.abs([1/np.sqrt(16)]+a[i])**2, c='g', label='ω = 13')
    elif i == 0:
        axes.plot(np.abs([1/np.sqrt(16)]+a[i])**2, c='k', label='Otros estados')
    else:
        axes.plot(np.abs([1/np.sqrt(16)]+a[i])**2, c='k')
axes.set_xlabel('Iteración')
axes.set_ylabel('Probabilidad')
axes.set_ylim(0,0.6)
axes.legend()
fig.savefig('../../img/grover2M.eps', format='eps')

# %%
plt.plot(np.abs([1/np.sqrt(16)]+a[0])**2, c='r')
plt.plot(np.abs([1/np.sqrt(16)]+a[-1])**2, c='b')
plt.xlabel('Iteración')
plt.ylabel('Probabilidad')
# Out:
# Text(0,0.5,'Probabilidad')

# %%
plt.plot(np.abs([1/np.sqrt(16)]+a[-1])**2)
plt.xlabel('Iteración')
plt.ylabel('Probabilidad')
# Out:
# Text(0,0.5,'Probabilidad')

# %%
for i in range(15):
    plt.plot(np.abs([1/np.sqrt(16)]+a[i])**2)
plt.xlabel('Iteración')
plt.ylabel('Probabilidad')
# Out:
# Text(0,0.5,'Probabilidad')

# %%
[-(13/256),-(13/256),-(13/256),-(13/256),-(13/256),-(13/256),-(13/256),-(13/256),-(13/256),-(13/256),-(13/256),-(13/256),-(13/256),-(13/256),-(13/256),251/256]

# %%
np.array(res[6].states[-1])
# Out:
# array(Quantum object: dims = [[2, 2, 2, 2], [1, 1, 1, 1]], shape = (16, 1), type = ket
# Qobj data =
# [[0.08201454-0.18928292j]
#  [0.08198888-0.18932485j]
#  [0.08211445-0.18901311j]
#  [0.0821375 -0.18961576j]
#  [0.08192332-0.18928866j]
#  [0.08218462-0.18917131j]
#  [0.08232985-0.18986378j]
#  [0.08273714-0.18906296j]
#  [0.08199489-0.18936172j]
#  [0.08214138-0.19012357j]
#  [0.08185422-0.18903717j]
#  [0.08216521-0.18920655j]
#  [0.08151934-0.18883144j]
#  [0.08193873-0.18950729j]
#  [0.08146689-0.18961357j]
#  [0.23455004-0.5533692j ]], dtype=object)
