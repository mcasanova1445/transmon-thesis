# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from qutip import *

# %%
res = []

for i in range(7): #7
    res.append(qload('it_{}'.format(i+1)))
# Out:
# Loaded Result object:
# Result object with mesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with mesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with mesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with mesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with mesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with mesolve data.
# --------------------------------
# states = True
# num_collapse = 0
# Loaded Result object:
# Result object with mesolve data.
# --------------------------------
# states = True
# num_collapse = 0

# %%
res[3].states[-1][0,0]
# Out:
# (0.05839737808545795-2.1190364125511767e-12j)

# %%
a = [[1/16],[1/16],[1/16],[1/16],[1/16],[1/16],[1/16],[1/16],[1/16],[1/16],[1/16],[1/16],[1/16],[1/16],[1/16],[1/16]]

for i in range(2):
    for j in range(2):
        for k in range(2):
            for l in range(2):
                for m in range(7): #7
                    a[8*i+4*j+2*k+l].append(np.abs(res[m].states[-1][8*i+4*j+2*k+l,8*i+4*j+2*k+l]))

# %%
[a[i][-1] for i in range(16)]
# Out:
# [0.06803146765790337,
#  0.0621758132825808,
#  0.06242433868356752,
#  0.05722980363934001,
#  0.07595231271275055,
#  0.07087380838753622,
#  0.061128843032924506,
#  0.05626365070699213,
#  0.06434579745612423,
#  0.058852825028835334,
#  0.058711301714720325,
#  0.05379975162652505,
#  0.07238253048305188,
#  0.06760454747484747,
#  0.0574000009927662,
#  0.05282320712123775]

# %%
fig, axes = plt.subplots(1, 1, sharex=True, figsize=(12,8))

for i in range(16):
    if i == 4:
        axes.plot(np.abs(a[i]), c='b', label='ω = 4')
    elif i == 5:
        axes.plot(np.abs(a[i]), c='g', label='ω = 5')
    elif i == 12:
        axes.plot(np.abs(a[i]), c='m', label='ω = 12')
    elif i == 13:
        axes.plot(np.abs(a[i]), c='c', label='ω = 13')
    elif i == 0:
        axes.plot(np.abs(a[i]), c='r', label='Estado base')
    elif i == 1:
        axes.plot(np.abs(a[i]), c='k', label='Otros estados')
    else:
        axes.plot(np.abs(a[i]), c='k')
#axes.plot(np.abs(a[0]), c='r')
axes.set_xlabel('Iteración')
axes.set_ylabel('Probabilidad')
axes.set_ylim(0,0.25)
axes.legend()
fig.savefig('../../img/grover3loss.eps', format='eps')

# %%
plt.plot(a[0])
plt.plot(a[-1])

# %%
s = 0
for i in range(16):
    s += a[i][-1]

s
# Out:
# 1.0000000000062472

# %%
np.array(res[0].states[-1])
# Out:
# array(Quantum object: dims = [[2, 2, 2, 2], [2, 2, 2, 2]], shape = (16, 16), type = oper, isherm = True
# Qobj data =
# [[0.04875766+5.52244239e-12j 0.01756872-2.27082486e-03j
#   0.0125092 -1.10087901e-03j 0.0051625 +4.58954419e-05j
#   0.01210125-3.03984413e-04j 0.00350501-1.53256563e-04j
#   0.00374522-4.65218344e-04j 0.00393789+1.44199387e-03j
#   0.02567023-8.70017624e-04j 0.00925742+6.05007512e-04j
#   0.00756184-1.11742990e-03j 0.00432005+1.14016291e-03j
#   0.00968133+3.89116188e-04j 0.00454383+5.35107033e-04j
#   0.004893  -2.42924901e-03j 0.02224585+8.19433883e-04j]
#  [0.01756872+2.27082486e-03j 0.05192874-4.86846152e-13j
#   0.00857355+2.28128137e-03j 0.01825149-1.85921982e-03j
#   0.00758579+5.28776168e-04j 0.01857531+5.37078021e-04j
#   0.00865466+2.33603375e-03j 0.01755724-4.13562842e-05j
#   0.01281777+9.28826756e-04j 0.03489145-1.91793613e-03j
#   0.00970158+1.44071327e-03j 0.01684523+3.95733542e-04j
#   0.01052514-2.16702754e-03j 0.01807775+5.71659814e-04j
# ...
